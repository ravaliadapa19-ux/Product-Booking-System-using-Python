# %%
import zepto_project
# Out:
# --- Welcome to Mini Cart ---
# 1. View Products
# 2. Add to Cart
# 3. Remove from Cart
# 4. View Cart
# 5. Checkout
# 6. Exit
# Enter your choice:  1
# Available Products:
# Apple - 120
# Bananas - 60
# Milk - 50
# Oil - 150
#
# --- Welcome to Mini Cart ---
# 1. View Products
# 2. Add to Cart
# 3. Remove from Cart
# 4. View Cart
# 5. Checkout
# 6. Exit
# Enter your choice:  2
# Available Products:
# Apple - 120
# Bananas - 60
# Milk - 50
# Oil - 150
# Enter product name to add:  oil
# Enter quantity:  2
# Available Products:
# Apple - 120
# Bananas - 60
# Milk - 50
# Oil - 150
#  Added 2 oil to cart.
#
#
# --- Welcome to Mini Cart ---
# 1. View Products
# 2. Add to Cart
# 3. Remove from Cart
# 4. View Cart
# 5. Checkout
# 6. Exit
# Enter your choice:  4
# Your Cart:
# Oil x2 = 300
# Total: ₹300
#
#
# --- Welcome to Mini Cart ---
# 1. View Products
# 2. Add to Cart
# 3. Remove from Cart
# 4. View Cart
# 5. Checkout
# 6. Exit
# Enter your choice:  5
# ...
